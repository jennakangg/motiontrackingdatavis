# %%
import json
from itertools import product
import numpy as np
import random
# Data structure to organize pair conditions
cam_velocities_per_motion_condition_given_obj_vel = {
    "contrast": {
        0: 0,
        7.5: 0,
        15.0: 0,
        30.0: 0,
    }
}

object_velocities = [
    # 7.5,
    # 15.0, 
    30.0
]

object_directions = {
    "horizontal_left": (-1, 0),
    "horizontal_right": (1, 0)
}

initial_ball_placements = {
    "horizontal_left": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
    },
    "horizontal_right": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
    }
}

initial_crosshair_placements = {
    "horizontal_left": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
    },
    "horizontal_right": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
    }
}

duration_mapping = {
    "horizontal_left": {
        0: (1.0, 1.5),
        7.5: (1.0, 1.5),
        15.0: (1.0, 1.5),
        30.0: (1.0, 1.5),
    },
    "horizontal_right": {
        0: (1.0, 1.5),
        7.5: (1.0, 1.5),
        15.0: (1.0, 1.5),
        30.0: (1.0, 1.5),
    }
}

color_JND = 1/100

color_thresholds = [
    # color_JND, 
    # color_JND * 1.5, 
    # color_JND * 6, 
    color_JND * 8,
    # 1.5
    ]

# Helper function to generate trial segments
def generate_segments_2_speeds(object_direction, object_velocity, duration, contrast_threshold):    
    return [
        {
            "object_motion": object_direction,
            "object_speed": object_velocity,
            "camera_motion": (0, 0),
            "camera_speed": 0,
            "duration": duration, 
            "contrast_intensity": contrast_threshold
        }
    ]

camera_transforms = [

     {"position": [1.647,1.453,-12.028],
     "rotation": [331.600,254.137,0.000]},

     {"position": [0.742,1.453,-11.745],
     "rotation": [329.200,251.072,0.000]},

     {"position": [7.231,1.453,-10.851],
     "rotation": [323.700,67.164,0.000]},

     {"position": [7.666,1.453,4.893],
     "rotation": [332.700,325.203,0.000]},
]

# Generate trial data
unique_trials = []
trial_id = 0
camera_forward = [
    2,
    4,
    6
]
for obj_velocity, (obj_motion_type, obj_direction) in product(
        object_velocities,
        object_directions.items()):
    
        for contrast_threshold in color_thresholds:

            initial_ball_placement = initial_ball_placements[obj_motion_type][obj_velocity]
            initial_crosshair_placement = initial_crosshair_placements[obj_motion_type][obj_velocity]
            duration = duration_mapping[obj_motion_type][obj_velocity]
            for cam_transform in camera_transforms:
                # cam_transform = random.choice(camera_transforms)
                initial_camera_position = cam_transform["position"]
                initial_camera_rotation = cam_transform["rotation"]


                segments_1 = generate_segments_2_speeds(obj_direction, obj_velocity, duration, contrast_threshold)
                cam_for_vel = random.choice(camera_forward)
                trial_positive = {
                    "trial_id": trial_id,
                    "initial_ball_placement": {"x": initial_ball_placement[0], "y": initial_ball_placement[1]},
                    "initial_crosshair_placement": {"x": initial_crosshair_placement[0], "y": initial_crosshair_placement[1]},
                    "initial_camera_position": {"x": initial_camera_position[0], "y": initial_camera_position[1], "z": initial_camera_position[2]},
                    "initial_camera_rotation": {"x": initial_camera_rotation[0], "y": initial_camera_rotation[1], "z": initial_camera_rotation[2]},
                    "camera_forward_velocity": 6,
                    "segments": segments_1
                }

                print(trial_positive)
    
                unique_trials.append(trial_positive)
                trial_id += 1

                
# Write trials to JSON
output_file = "trial_ids_fps/trials_test.json"
with open(output_file, mode='w') as file:
    json.dump(unique_trials, file, indent=4)

print(f"Trials saved to {output_file}")
print(len(unique_trials))
# Out:
# {'trial_id': 0, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': -4.393, 'y': 1.456, 'z': -0.303}, 'initial_camera_rotation': {'x': 346.7, 'y': 133.996, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 1, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': -1.612, 'y': 1.453, 'z': -1.525}, 'initial_camera_rotation': {'x': 331.1, 'y': 114.713, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 2, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 3, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 0.742, 'y': 1.453, 'z': -11.745}, 'initial_camera_rotation': {'x': 329.2, 'y': 251.072, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 4, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.231, 'y': 1.453, 'z': -10.851}, 'initial_camera_rotation': {'x': 323.7, 'y': 67.164, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 5, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (-1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 6, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': -4.393, 'y': 1.456, 'z': -0.303}, 'initial_camera_rotation': {'x': 346.7, 'y': 133.996, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 7, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': -1.612, 'y': 1.453, 'z': -1.525}, 'initial_camera_rotation': {'x': 331.1, 'y': 114.713, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 8, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 9, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 0.742, 'y': 1.453, 'z': -11.745}, 'initial_camera_rotation': {'x': 329.2, 'y': 251.072, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 10, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.231, 'y': 1.453, 'z': -10.851}, 'initial_camera_rotation': {'x': 323.7, 'y': 67.164, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# {'trial_id': 11, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 6, 'segments': [{'object_motion': (1, 0), 'object_speed': 30.0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (1.0, 1.5), 'contrast_intensity': 0.08}]}
# Trials saved to trial_ids_fps/trials_test.json
# 12

# %%
import json
import random

# Function to generate a random sequence of trials

def generate_random_trials(input_file, output_file, repetitions):
    # Load trials from input JSON
    with open(input_file, mode='r') as file:
        trials = json.load(file)

    # Create repeated and shuffled trials
    all_trials = []
    for _ in range(repetitions):
        random.shuffle(trials)
        all_trials.extend(trials)

    # # Assign new trial IDs to preserve uniqueness
    # for idx, trial in enumerate(all_trials):
    #     trial["trial_num"] = idx
    # Save randomized trials to output JSON
    with open(output_file, mode='w') as file:
        json.dump(all_trials, file, indent=4)

    print(f"Randomized trials with {repetitions} repetitions saved to {output_file}")
    print(f"Total trials: {len(all_trials)}")

# Parameters

for i in range(0,2):
    input_file = "trial_ids_fps/trials_soccer_pilot.json"  # Path to the input file
    output_file = f"trials_fps/generated_trials_eval_soccer_{i}.json"  # Path to save the randomized output file
    repetitions = 5  # Number of repetitions

    # Generate the randomized sequence
    generate_random_trials(input_file, output_file, repetitions)
# Out:
# Randomized trials with 5 repetitions saved to trials_segments/generated_trials_eval_soccer_0.json
# Total trials: 40
# Randomized trials with 5 repetitions saved to trials_segments/generated_trials_eval_soccer_1.json
# Total trials: 40
