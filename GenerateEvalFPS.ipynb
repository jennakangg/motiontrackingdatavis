# %%
import json
from itertools import product
import numpy as np
import random
# Data structure to organize pair conditions
cam_velocities_per_motion_condition_given_obj_vel = {
    "contrast": {
        0: 0,
        7.5: 0,
        15.0: 0,
        30.0: 0,
    }
}

object_velocities = [
    # 7.5,
    # 15.0, 
    # 30.0
    10
    # 15, 
    # 20
]

object_directions = {
    "horizontal_left": (-1, 0),
    "horizontal_right": (1, 0)
}

initial_ball_placements = {
    "horizontal_left": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
        10: (.5, 0.5),
        20: (.5, 0.5),
    },
    "horizontal_right": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
        10: (.5, 0.5),
        20: (.5, 0.5),
    }
}

initial_crosshair_placements = {
    "horizontal_left": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
        10: (.5, 0.5),
        20: (.5, 0.5),
    },
    "horizontal_right": {
        0: (.5, 0.5),
        7.5: (.5, 0.5),
        15.0: (.5, 0.5),
        30.0: (.5, 0.5),
        10: (.5, 0.5),
        20: (.5, 0.5),
    }
}

duration_mapping = {
    "horizontal_left": {
        0: (1.0, 1.5),
        7.5: (1.0, 1.5),
        15.0: (1.0, 1.5),
        30.0: (1.0, 1.5),
        10: (1.0, 1.5),
        20: (1.0, 1.5),
    },
    "horizontal_right": {
        0: (1.0, 1.5),
        7.5: (1.0, 1.5),
        15.0: (1.0, 1.5),
        30.0: (1.0, 1.5),
        10: (1.0, 1.5),
        20: (1.0, 1.5),
    }
}

color_JND = 1/63.333333333

color_thresholds = [
    # color_JND, 
    color_JND * 1.5, 
    color_JND * 6, 
    color_JND * 8,
    # 1.5
    ]

# Helper function to generate trial segments
def generate_segments_2_speeds(object_direction, object_velocity, duration, contrast_threshold, velocity_delta):    
    return [
         {
            "object_motion": object_direction,
            "object_speed": object_velocity,
            "camera_motion": (0, 0),
            "camera_speed": 0,
            "duration": (0.5, 1), 
            "contrast_intensity": contrast_threshold
        },
        {
            "object_motion": object_direction,
            "object_speed": object_velocity + object_velocity*velocity_delta,
            "camera_motion": (0, 0),
            "camera_speed": 0,
            "duration": (0.5, 1), 
            "contrast_intensity": contrast_threshold
        }
    ]

camera_transforms = [

     {"position": [1.647,1.453,-12.028],
     "rotation": [331.600,254.137,0.000]},

     {"position": [0.742,1.453,-11.745],
     "rotation": [329.200,251.072,0.000]},

     {"position": [7.666,1.453,4.893],
     "rotation": [332.700,325.203,0.000]},

     {"position": [4.811,1.453,6.690],
     "rotation": [327.800,358.345,0.000]},

     {"position": [4.670,1.453,11.835],
     "rotation": [330.300,266.772,0.000]},
]

# Generate trial data
unique_trials = []
trial_id = 0
camera_forward = [
    2,
    4
]

velocity_deltas = [1, -1, 2, -2]
for obj_velocity, (obj_motion_type, obj_direction) in product(
        object_velocities,
        object_directions.items()):
    
        for contrast_threshold in color_thresholds:
            for delta in velocity_deltas:

                initial_ball_placement = initial_ball_placements[obj_motion_type][obj_velocity]
                initial_crosshair_placement = initial_crosshair_placements[obj_motion_type][obj_velocity]
                duration = duration_mapping[obj_motion_type][obj_velocity]
                # for cam_transform in camera_transforms:
                cam_transform = random.choice(camera_transforms)
                initial_camera_position = cam_transform["position"]
                initial_camera_rotation = cam_transform["rotation"]


                segments_1 = generate_segments_2_speeds(obj_direction, obj_velocity, duration, contrast_threshold, delta)
                cam_for_vel = random.choice(camera_forward)
                trial_positive = {
                    "trial_id": trial_id,
                    "initial_ball_placement": {"x": initial_ball_placement[0], "y": initial_ball_placement[1]},
                    "initial_crosshair_placement": {"x": initial_crosshair_placement[0], "y": initial_crosshair_placement[1]},
                    "initial_camera_position": {"x": initial_camera_position[0], "y": initial_camera_position[1], "z": initial_camera_position[2]},
                    "initial_camera_rotation": {"x": initial_camera_rotation[0], "y": initial_camera_rotation[1], "z": initial_camera_rotation[2]},
                    "camera_forward_velocity": random.choice(camera_forward),
                    "segments": segments_1
                }

                print(trial_positive)

                unique_trials.append(trial_positive)
                trial_id += 1

                
# Write trials to JSON
output_file = "trial_ids_fps/trials_fps_jenna_2_segments.json"
with open(output_file, mode='w') as file:
    json.dump(unique_trials, file, indent=4)

print(f"Trials saved to {output_file}")
print(len(unique_trials))
# Out:
# {'trial_id': 0, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.67, 'y': 1.453, 'z': 11.835}, 'initial_camera_rotation': {'x': 330.3, 'y': 266.772, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (-1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 1, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.811, 'y': 1.453, 'z': 6.69}, 'initial_camera_rotation': {'x': 327.8, 'y': 358.345, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (-1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 2, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (-1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 3, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 0.742, 'y': 1.453, 'z': -11.745}, 'initial_camera_rotation': {'x': 329.2, 'y': 251.072, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (-1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 4, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (-1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 5, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.67, 'y': 1.453, 'z': 11.835}, 'initial_camera_rotation': {'x': 330.3, 'y': 266.772, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (-1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 6, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (-1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 7, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (-1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 8, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (-1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 9, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.811, 'y': 1.453, 'z': 6.69}, 'initial_camera_rotation': {'x': 327.8, 'y': 358.345, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (-1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 10, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (-1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 11, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.811, 'y': 1.453, 'z': 6.69}, 'initial_camera_rotation': {'x': 327.8, 'y': 358.345, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (-1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (-1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 12, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.67, 'y': 1.453, 'z': 11.835}, 'initial_camera_rotation': {'x': 330.3, 'y': 266.772, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 13, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 14, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 15, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}, {'object_motion': (1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.023684210526440444}]}
# {'trial_id': 16, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 17, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 4, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 18, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 19, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.811, 'y': 1.453, 'z': 6.69}, 'initial_camera_rotation': {'x': 327.8, 'y': 358.345, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}, {'object_motion': (1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.09473684210576178}]}
# {'trial_id': 20, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 1.647, 'y': 1.453, 'z': -12.028}, 'initial_camera_rotation': {'x': 331.6, 'y': 254.137, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (1, 0), 'object_speed': 20, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 21, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 7.666, 'y': 1.453, 'z': 4.893}, 'initial_camera_rotation': {'x': 332.7, 'y': 325.203, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (1, 0), 'object_speed': 0, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 22, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 0.742, 'y': 1.453, 'z': -11.745}, 'initial_camera_rotation': {'x': 329.2, 'y': 251.072, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (1, 0), 'object_speed': 30, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# {'trial_id': 23, 'initial_ball_placement': {'x': 0.5, 'y': 0.5}, 'initial_crosshair_placement': {'x': 0.5, 'y': 0.5}, 'initial_camera_position': {'x': 4.811, 'y': 1.453, 'z': 6.69}, 'initial_camera_rotation': {'x': 327.8, 'y': 358.345, 'z': 0.0}, 'camera_forward_velocity': 2, 'segments': [{'object_motion': (1, 0), 'object_speed': 10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}, {'object_motion': (1, 0), 'object_speed': -10, 'camera_motion': (0, 0), 'camera_speed': 0, 'duration': (0.5, 1), 'contrast_intensity': 0.12631578947434904}]}
# Trials saved to trial_ids_fps/trials_fps_jenna_2_segments.json
# 24

# %%
import json
import random

# Function to generate a random sequence of trials

def generate_random_trials(input_file, output_file, repetitions):
    # Load trials from input JSON
    with open(input_file, mode='r') as file:
        trials = json.load(file)

    # Create repeated and shuffled trials
    all_trials = []
    for _ in range(repetitions):
        random.shuffle(trials)
        all_trials.extend(trials)

    # # Assign new trial IDs to preserve uniqueness
    # for idx, trial in enumerate(all_trials):
    #     trial["trial_num"] = idx
    # Save randomized trials to output JSON
    with open(output_file, mode='w') as file:
        json.dump(all_trials, file, indent=4)

    print(f"Randomized trials with {repetitions} repetitions saved to {output_file}")
    print(f"Total trials: {len(all_trials)}")

# Parameters

for i in range(0,1):
    input_file = "trial_ids_fps/trials_fps_jenna_2_segments.json"  # Path to the input file
    output_file = f"trials_fps/generated_trials_jenna_2_segments_{i}.json"  # Path to save the randomized output file
    repetitions = 5  # Number of repetitions

    # Generate the randomized sequence
    generate_random_trials(input_file, output_file, repetitions)
# Out:
# Randomized trials with 5 repetitions saved to trials_fps/generated_trials_jenna_2_segments_0.json
# Total trials: 120
