# %%
import pandas as pd
import numpy as np
import json
import scipy.signal
import matplotlib.pyplot as plt

def vel_filter(ang_vel_all):
    b, a = scipy.signal.butter(2, 0.1, 'lowpass')
    return scipy.signal.filtfilt(b, a, ang_vel_all)

# Load data
data = pd.read_csv('GazeDataEval/gaze_data_eval_video_testing.csv', sep=',')

# Load JSON file for trial details
with open("eval_trial_videos.json", "r") as f:
    trial_details = json.load(f)

# Process segment JSON data
def process_segments(trial_details):
    trial_data = []
    for trial in trial_details:
        trial_id = trial['trial_id']
        video_path = trial['video_path']
        initial_crosshair = trial['initial_crosshair_placement']

        trial_data.append({
            'trial_id': trial_id,
            'video_path': video_path,
            'initial_crosshair_x': initial_crosshair['x'],
            'initial_crosshair_y': initial_crosshair['y']
        })
    return pd.DataFrame(trial_data)

segment_df = process_segments(trial_details)

# Add columns if needed
def add_video_columns(df):
    video_names = df[['trial_id', 'video_path']].rename(columns={'video_path': 'associated_video'})
    df = df.merge(video_names, on='trial_id', how='left')
    return df

segment_df = add_video_columns(segment_df)

# Map TrialID to segments in CSV data
def map_camera_motion_and_kick_force(data_df, segment_df):
    data_df = data_df.merge(
        segment_df[['trial_id', 'initial_crosshair_x', 'initial_crosshair_y', 'video_path']],
        left_on='TrialID', right_on='trial_id', how='left'
    )
    return data_df

data = map_camera_motion_and_kick_force(data, segment_df)

# Screen parameters
# screen_width = 2560
# screen_height = 1440
# screen_diagonal_size = 27.5  # inches
# distance_to_screen = 0.5842  # meters

screen_width = 3840
screen_height = 2160

# FILTERING FOR VALID TRIALS
data = data[data['TrialSection'] == "TRIAL"]
data = data[data['TrialID'] == 1]

# Process data
data['RelativeTime'] = data.groupby('TrialNumber')['Time'].transform(lambda x: x - x.min())
data['MappedPogX'] = data['BestPogX'] * screen_width
data['MappedPogY'] = data['BestPogY'] * screen_height

# Apply filter to each trial
def apply_filter_per_trial(df, column_name, new_column_name):
    df[new_column_name] = df.groupby('TrialNumber')[column_name].transform(lambda x: vel_filter(x.fillna(0)))
    return df

data = apply_filter_per_trial(data, 'MappedPogX', 'FilteredPogX')
data = apply_filter_per_trial(data, 'MappedPogY', 'FilteredPogY')

# Discard trials with high angular error
def discard_trials_with_high_angular_error(df, angular_error_threshold):
    trials_to_discard = df[df['AngularError'] > angular_error_threshold]['TrialNumber'].unique()
    return df[~df['TrialNumber'].isin(trials_to_discard)]

# angular_error_threshold = 30.0
# data = discard_trials_with_high_angular_error(data, angular_error_threshold)
import os
from moviepy import VideoFileClip

# Function to get video duration
def get_video_duration(video_path):
    try:
        clip = VideoFileClip(video_path)
        duration = clip.duration  # Duration in seconds
        clip.close()
        return duration
    except Exception as e:
        print(f"Error processing video {video_path}: {e}")
        return None

# Function to create a dictionary mapping video paths to durations
def create_video_duration_mapping(segment_df, videos_dir):
    # Ensure paths are joined correctly
    segment_df['full_video_path'] = segment_df['video_path'].apply(lambda path: os.path.join(videos_dir, path))
    video_duration_mapping = {
        row['video_path']: get_video_duration(row['full_video_path']) for _, row in segment_df.iterrows()
    }
    return video_duration_mapping

# Define videos directory
videos_dir = "EvalVideos"  # Ensure this is the correct directory path

# Create the mapping
video_duration_mapping = create_video_duration_mapping(segment_df, videos_dir)

# Display the mapping
print(video_duration_mapping)
# Add a column to convert TimeTick (CPU ticks) to seconds, starting at zero and ending at the video duration
def convert_cpu_ticks_to_seconds(data, video_duration_mapping):
    # Map the video duration from the dictionary to the dataframe
    data['VideoDuration'] = data['video_path'].map(video_duration_mapping)
    
    # Normalize TimeTick by subtracting the minimum TimeTick per trial
    data['NormalizedTimeTick'] = data.groupby('TrialID')['TimeTick'].transform(lambda x: x - x.min())
    
    # Scale TimeTick such that the maximum normalized tick corresponds to the video duration
    data['TimeTickInSeconds'] = (
        data['NormalizedTimeTick']
        * data['VideoDuration']
        / data.groupby('TrialID')['NormalizedTimeTick'].transform('max')
    )
    
    return data

# Apply the conversion
data = convert_cpu_ticks_to_seconds(data, video_duration_mapping)

# Save the TimeTickInSeconds column to a text file
output_file = "TimeTickInSeconds.txt"
data['TimeTickInSeconds'].to_csv(output_file, index=False, header=False)

print(f"TimeTickInSeconds column saved to '{output_file}'.")
# Out:
# {'fps_clip_1_clip.mp4': 3.64, 'dog_running.mp4': 3.0}
# TimeTickInSeconds column saved to 'TimeTickInSeconds.txt'.

# %% [markdown]
# Helper functions

# %%
import os
import cv2
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.animation import FFMpegWriter

def remap_filled_segmentation(object_points, video_width, video_height, screen_width, screen_height):
    """
    Remap filled segmentation points to fit the screen size based on the aspect ratio of the video and screen.

    Args:
        object_points: np.array, the points defining the filled object segmentation.
        video_width: int, width of the video.
        video_height: int, height of the video.
        screen_width: int, width of the screen.
        screen_height: int, height of the screen.

    Returns:
        np.array: Remapped segmentation points.
    """
    # Scale and adjust points
    remapped_points = np.copy(object_points)  # Avoid modifying the original points
    remapped_points[:, 1] = object_points[:, 0]/video_height * screen_height
    remapped_points[:, 0] = object_points[:, 1]/video_width * screen_width

    return remapped_points


def get_video_dimensions(mask_directory):
    """
    Detect video dimensions from the first mask image in the directory.

    Args:
        mask_directory: str, path to the directory containing mask images.

    Returns:
        tuple: (video_width, video_height)
    """
    for file_name in os.listdir(mask_directory):
        if file_name.endswith(".png"):
            mask_path = os.path.join(mask_directory, file_name)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            return mask.shape[1], mask.shape[0]  # (width, height)
    return 512, 320  # Default to 1280x720 if no masks are found

def calculate_centroid(points):
    """
    Calculate the centroid of a set of points.

    Args:
        points: np.array, array of points (x, y).

    Returns:
        tuple: (centroid_x, centroid_y)
    """
    if len(points) == 0:
        return None
    centroid_x = np.mean(points[:, 0])
    centroid_y = np.mean(points[:, 1])
    return centroid_x, centroid_y


def calculate_velocity(centroid1, centroid2, time_delta, screen_width, screen_height, distance_from_screen):
    """
    Calculate the velocity (on-screen and angular) of an object.

    Args:
        centroid1: tuple, previous centroid (x, y).
        centroid2: tuple, current centroid (x, y).
        time_delta: float, time difference between frames.
        screen_width: int, width of the screen.
        screen_height: int, height of the screen.
        distance_from_screen: float, distance from the screen (meters).

    Returns:
        tuple: (on_screen_velocity, angular_velocity)
    """
    if centroid1 is None or centroid2 is None or time_delta == 0:
        return 0, 0

    dx = (centroid2[0] - centroid1[0]) / screen_width
    dy = (centroid2[1] - centroid1[1]) / screen_height

    # On-screen velocity in normalized units
    on_screen_velocity = np.sqrt(dx**2 + dy**2) / time_delta

    # Angular velocity (degrees/sec)
    angular_velocity_radians = np.arctan(on_screen_velocity / distance_from_screen)
    angular_velocity_degrees = np.degrees(angular_velocity_radians)

    return on_screen_velocity, angular_velocity_degrees

# %% [markdown]
# Params

# %%
output_video_path = "fps_clip_1_clip_annotated_video.mp4"
mask_directory = "fps_clip_1_clip_masks"
frame_output_directory = "fps_clip_1_clip_frames_output"
object_id = 8
distance_from_screen = 0.5  # Distance from screen in meters

# Detect video dimensions from masks
video_width, video_height = get_video_dimensions(mask_directory)

# %%
import matplotlib.pyplot as plt

# Ensure the output directory for frames exists
if not os.path.exists(frame_output_directory):
    os.makedirs(frame_output_directory)

# Prepare video writer
fps = 30
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (screen_width, screen_height))

# Variables to track previous centroid and time
previous_centroid = None
previous_time = None

# Lists to store velocity and time for plotting
velocity_data = []
time_data = []

unique_frames = data['VideoFrameNumber'].unique()
for frame_idx in unique_frames:
    # Match gaze data for the current frame
    frame_data = data[data['VideoFrameNumber'] == frame_idx]
    time_tick = frame_data['TimeTickInSeconds'].iloc[0]
    
    gaze_points = frame_data[['MappedPogX', 'MappedPogY']].to_numpy()

    # Load mask points for the object
    mask_file = os.path.join(mask_directory, f"frame_{frame_idx}_points.json")
    object_points = None
    if os.path.exists(mask_file):
        with open(mask_file, 'r') as f:
            points_data = json.load(f)

        object_points = np.array(points_data[str(object_id)]['points']) if str(object_id) in points_data else None

    # Draw annotations on a black background
    frame = np.zeros((screen_height, screen_width, 3), dtype=np.uint8)
    
    # Always process and save the frame
    if object_points is not None:
        remapped_object_points = remap_filled_segmentation(object_points, video_width, video_height, screen_width, screen_height)
        for point in remapped_object_points:
            cv2.circle(frame, (int(point[0]), int(point[1])), radius=2, color=(255, 255, 255), thickness=-1)

        # Calculate centroid
        centroid = calculate_centroid(remapped_object_points)
        if centroid:
            cv2.circle(frame, (int(centroid[0]), int(centroid[1])), radius=5, color=(0, 255, 0), thickness=-1)

            # Calculate velocity if we have a previous centroid
            if previous_centroid is not None and previous_time is not None:
                time_delta = (time_tick - previous_time)
                on_screen_velocity, angular_velocity = calculate_velocity(
                    previous_centroid, centroid, time_delta, screen_width, screen_height, distance_from_screen
                )
                print(f"Frame {frame_idx}: On-Screen Velocity: {on_screen_velocity:.2f}, Angular Velocity: {angular_velocity:.2f} degrees/sec")

                # Store velocity and time for plotting
                velocity_data.append(on_screen_velocity)
                time_data.append(time_tick)

            # Update previous centroid and time
            previous_centroid = centroid
            previous_time = time_tick

    # Always add gaze points, even if no object is detected
    for gaze_point in gaze_points:
        gaze_x, gaze_y = int(gaze_point[0]), int(gaze_point[1])
        cv2.circle(frame, (gaze_x, gaze_y), radius=5, color=(0, 0, 255), thickness=-1)
    
    # Write annotated frame to video
    video_writer.write(frame)

    # Save each frame as an image
    frame_filename = os.path.join(frame_output_directory, f"frame_{frame_idx}.png")
    cv2.imwrite(frame_filename, frame)

    print(f"Processed frame {frame_idx}", end='\r')

video_writer.release()
print("\nFinished creating velocity-annotated video.")

# Plot velocity vs. time
plt.figure(figsize=(10, 6))
plt.plot(time_data, velocity_data, label="On-Screen Velocity", marker='o')
plt.xlabel("Time (seconds)")
plt.ylabel("Velocity (pixels/second)")
plt.title("On-Screen Velocity Over Time")
plt.legend()
plt.grid()
plt.show()
# Out:
# Frame 1: On-Screen Velocity: 5.16, Angular Velocity: 84.47 degrees/sec
# Frame 2: On-Screen Velocity: 1.92, Angular Velocity: 75.42 degrees/sec
# Frame 3: On-Screen Velocity: 1.49, Angular Velocity: 71.45 degrees/sec
# Frame 4: On-Screen Velocity: 0.87, Angular Velocity: 60.24 degrees/sec
# Frame 5: On-Screen Velocity: 2.04, Angular Velocity: 76.20 degrees/sec
# Frame 6: On-Screen Velocity: 0.00, Angular Velocity: 0.08 degrees/sec
# Frame 7: On-Screen Velocity: 1.78, Angular Velocity: 74.32 degrees/sec
# Frame 8: On-Screen Velocity: 0.69, Angular Velocity: 53.96 degrees/sec
# Frame 9: On-Screen Velocity: 0.00, Angular Velocity: 0.17 degrees/sec
# Frame 10: On-Screen Velocity: 0.98, Angular Velocity: 63.03 degrees/sec
# Frame 11: On-Screen Velocity: 0.65, Angular Velocity: 52.58 degrees/sec
# Frame 12: On-Screen Velocity: 0.31, Angular Velocity: 32.21 degrees/sec
# Frame 13: On-Screen Velocity: 0.90, Angular Velocity: 60.99 degrees/sec
# Frame 14: On-Screen Velocity: 0.57, Angular Velocity: 48.76 degrees/sec
# Frame 15: On-Screen Velocity: 0.28, Angular Velocity: 29.31 degrees/sec
# Frame 16: On-Screen Velocity: 1.55, Angular Velocity: 72.14 degrees/sec
# Frame 17: On-Screen Velocity: 0.83, Angular Velocity: 58.85 degrees/sec
# Frame 18: On-Screen Velocity: 0.00, Angular Velocity: 0.31 degrees/sec
# Frame 19: On-Screen Velocity: 0.80, Angular Velocity: 58.03 degrees/sec
# Frame 20: On-Screen Velocity: 0.81, Angular Velocity: 58.45 degrees/sec
# Frame 21: On-Screen Velocity: 0.85, Angular Velocity: 59.50 degrees/sec
# Frame 22: On-Screen Velocity: 1.52, Angular Velocity: 71.81 degrees/sec
# Frame 23: On-Screen Velocity: 0.84, Angular Velocity: 59.36 degrees/sec
# Frame 24: On-Screen Velocity: 0.00, Angular Velocity: 0.07 degrees/sec
# Frame 25: On-Screen Velocity: 1.57, Angular Velocity: 72.38 degrees/sec
# Frame 26: On-Screen Velocity: 0.37, Angular Velocity: 36.43 degrees/sec
# Frame 27: On-Screen Velocity: 0.94, Angular Velocity: 62.02 degrees/sec
# Frame 28: On-Screen Velocity: 0.84, Angular Velocity: 59.20 degrees/sec
# Frame 29: On-Screen Velocity: 0.84, Angular Velocity: 59.26 degrees/sec
# Frame 30: On-Screen Velocity: 0.90, Angular Velocity: 60.95 degrees/sec
# Frame 31: On-Screen Velocity: 0.45, Angular Velocity: 42.21 degrees/sec
# Frame 32: On-Screen Velocity: 0.39, Angular Velocity: 37.62 degrees/sec
# Frame 33: On-Screen Velocity: 0.00, Angular Velocity: 0.18 degrees/sec
# Frame 61: On-Screen Velocity: 0.62, Angular Velocity: 51.28 degrees/sec
# Frame 62: On-Screen Velocity: 6.21, Angular Velocity: 85.40 degrees/sec
# Frame 63: On-Screen Velocity: 2.77, Angular Velocity: 79.76 degrees/sec
# Frame 64: On-Screen Velocity: 7.35, Angular Velocity: 86.11 degrees/sec
# Frame 65: On-Screen Velocity: 1.93, Angular Velocity: 75.45 degrees/sec
# Frame 66: On-Screen Velocity: 1.66, Angular Velocity: 73.23 degrees/sec
# Frame 67: On-Screen Velocity: 1.34, Angular Velocity: 69.55 degrees/sec
# Frame 68: On-Screen Velocity: 0.86, Angular Velocity: 59.71 degrees/sec
# Frame 69: On-Screen Velocity: 0.59, Angular Velocity: 49.65 degrees/sec
# Frame 70: On-Screen Velocity: 2.21, Angular Velocity: 77.27 degrees/sec
# Frame 71: On-Screen Velocity: 0.43, Angular Velocity: 40.55 degrees/sec
# Frame 72: On-Screen Velocity: 0.00, Angular Velocity: 0.06 degrees/sec
# Frame 73: On-Screen Velocity: 1.63, Angular Velocity: 72.97 degrees/sec
# Frame 74: On-Screen Velocity: 0.40, Angular Velocity: 38.94 degrees/sec
# Frame 75: On-Screen Velocity: 1.26, Angular Velocity: 68.29 degrees/sec
# Frame 76: On-Screen Velocity: 1.09, Angular Velocity: 65.45 degrees/sec
# Frame 77: On-Screen Velocity: 0.24, Angular Velocity: 25.58 degrees/sec
# Frame 78: On-Screen Velocity: 1.77, Angular Velocity: 74.21 degrees/sec
# Frame 79: On-Screen Velocity: 1.14, Angular Velocity: 66.33 degrees/sec
# Frame 80: On-Screen Velocity: 1.81, Angular Velocity: 74.58 degrees/sec
# Frame 81: On-Screen Velocity: 0.00, Angular Velocity: 0.16 degrees/sec
# Frame 82: On-Screen Velocity: 2.52, Angular Velocity: 78.77 degrees/sec
# Frame 83: On-Screen Velocity: 1.46, Angular Velocity: 71.13 degrees/sec
# Frame 84: On-Screen Velocity: 0.00, Angular Velocity: 0.10 degrees/sec
# Frame 85: On-Screen Velocity: 2.60, Angular Velocity: 79.11 degrees/sec
# Frame 86: On-Screen Velocity: 1.21, Angular Velocity: 67.56 degrees/sec
# Processed frame 107
# Finished creating velocity-annotated video.

# %%
from moviepy import VideoFileClip

def get_video_length(video_path):
    """
    Get the exact duration of a video in seconds.

    Args:
        video_path (str): Path to the video file.

    Returns:
        float: Duration of the video in seconds.
    """
    try:
        # Load the video clip
        clip = VideoFileClip(video_path)
        duration = clip.duration  # Duration in seconds
        clip.close()  # Release resources
        return duration
    except Exception as e:
        print(f"Error getting duration for video {video_path}: {e}")
        return None

# Example usage:
video_path = "fps_clip_1_clip_annotated_video.mp4"
video_duration = get_video_length(video_path)
if video_duration is not None:
    print(f"Video Duration: {video_duration} seconds")
# Out:
# Video Duration: 3.57 seconds

# %%
import json
import random

# Function to generate a random sequence of trials

def generate_random_trials(input_file, output_file, repetitions):
    # Load trials from input JSON
    with open(input_file, mode='r') as file:
        trials = json.load(file)

    # Create repeated and shuffled trials
    all_trials = []
    for _ in range(repetitions):
        random.shuffle(trials)
        all_trials.extend(trials)

    # # Assign new trial IDs to preserve uniqueness
    # for idx, trial in enumerate(all_trials):
    #     trial["trial_num"] = idx
    # Save randomized trials to output JSON
    with open(output_file, mode='w') as file:
        json.dump(all_trials, file, indent=4)

    print(f"Randomized trials with {repetitions} repetitions saved to {output_file}")
    print(f"Total trials: {len(all_trials)}")

# Parameters

for i in range(0,2):
    input_file = "trial_ids_segments/trials_FINAL_monde.json"  # Path to the input file
    output_file = f"trials_segments/generated_trials_FINAL_monde_{i}.json"  # Path to save the randomized output file
    repetitions = 5  # Number of repetitions

    # Generate the randomized sequence
    generate_random_trials(input_file, output_file, repetitions)
